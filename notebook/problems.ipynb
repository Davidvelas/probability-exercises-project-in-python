# %% [markdown]
# # Probability exercises

# %% [markdown]
# ## Exercise 1
#
# Two dices are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7.  A simulation is a repetition of the same experiment multiple times to observe its behavior:
#
# - Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices).
# - Keep track of the number of times that the sum was either greater than 7 or an even number.
# - Divide the number from step 2 by the number of iterations (1000).

# %%
# TODO
import numpy as np

# %%
dice1 = np.random.randint(1,7,size = 1000)
dice2 = np.random.randint(1,7,size = 1000)

result = dice1 + dice2

greater_7 = np.sum(result > 7)
evens = np.sum(result %2 == 0)

print('Number of times sum is greater then 7: ', greater_7)
print ('Number of times sum are even: ', evens)


probability1 = greater_7 / 1000
probability2 = evens / 1000 

print('Probability for greater then 7: ', probability1)
print ('Probability for even numbers: ', probability2)
# Out:
# Number of times sum is greater then 7:  398
# Number of times sum are even:  502
# Probability for greater then 7:  0.398
# Probability for even numbers:  0.502

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. Take all of the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
import random
import pandas as pd
random.seed(42)
ball_box = {}

# Create the box of balls
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

#print(ball_box)
            
# TODO
n_simulations = 1000
count_1 = 0
count_2 = 0

for i in range(n_simulations):
    colors = []

    # Take 5 balls from the box
    for i in range(5):
        colors.append(ball_box[random.randint(0, 59)])

    #print(colors)
    #df = pd.DataFrame(colors,columns=["A","B","C","D","E"])
    
    colors = np.array(colors)
    nw = sum(colors == "White")
    nr = sum(colors == "Red")
    ng = sum(colors == "Green")
    if nw == 3 and nr == 2:
        count_1 += 1
    if nw == 5 or nr == 5 or ng == 5:
        count_2 += 1
    
print(colors)
print(nw)
print(nr)
print(ng)
print(f"The probability of 3 whites an 2 red is: %.3f" % (count_1/n_simulations*100),"%")
print(f"The probability of having the same colours is: %.3f" % (count_2/n_simulations*100),"%")
# Out:
# ['Green' 'White' 'Red' 'Green' 'Green']
# 1
# 1
# 3
# The probability of 3 whites an 2 red is: 0.600 %
# The probability of having the same colours is: 4.600 %
